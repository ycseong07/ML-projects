# %% [markdown]
# # __[ 패스트캠퍼스] Model-based Methods__

# %% [markdown]
# # <br>__1. Data: NASA Bearing Dataset__

# %% [markdown]
# - 데이터 description <br>
#     - NASA Bearing Dataset은 NSF I/UCR Center의 Intelligent Maintenance System의 4개의 bearing에서 고장이 발생할 때까지 10분 단위로 수집된 센서 데이터이다. 본 데이터셋은 특정 구간에서 기록된 1-second vibration signal snapshots을 나타내는 여러 개의 파일로 구성되어 있다. 각 파일은 20 kHz 단위로 샘플링 된 20,480개의 data point를 포함하고 있으며, 각 파일의 이름은 데이터가 수집된 시간을 의미한다. 해당 데이터셋은 크게 3개의 데이터를 포함하고 있으며, 본 실습에서 사용하는 데이터는 bearing 1에서 outer race failure가 발생할 때까지 수집된 센서 데이터이다. <br><br>
# - 변수 설명
#     - 독립 변수 (4개): Bearing1, Bearing2, Bearing3, Bearing4 <br><br>
# - 출처: https://ti.arc.nasa.gov/tech/dash/groups/pcoe/prognostic-data-repository/

# %% [markdown]
# <img src="https://i.imgur.com/dfFzn3H.jpg" width="600">

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Step1. 데이터 불러오기

# %%
# 데이터 불러오기
merged_data = pd.read_csv('../data/anomaly/merged_dataset.csv', index_col=0)
merged_data.index = pd.to_datetime(merged_data.index)
merged_data.head()
# Out:
#                      Bearing 1  Bearing 2  Bearing 3  Bearing 4  anomaly  \
# 2004-02-12 10:32:39   0.058333   0.071832   0.083242   0.043067    False
# 2004-02-12 10:42:39   0.058995   0.074006   0.084435   0.044541    False
# 2004-02-12 10:52:39   0.060236   0.074227   0.083926   0.044443    False
# 2004-02-12 11:02:39   0.061455   0.073844   0.084457   0.045081    False
# 2004-02-12 11:12:39   0.061361   0.075609   0.082837   0.045118    False
#
#                     data_type
# 2004-02-12 10:32:39     train
# 2004-02-12 10:42:39     train
# 2004-02-12 10:52:39     train
# 2004-02-12 11:02:39     train
# 2004-02-12 11:12:39     train

# %%
# 전체 기간의 데이터 분포 확인
merged_data.plot(figsize = (12, 6))
plt.axvline(merged_data.index[int(len(merged_data) * 0.5)], c='black')
plt.axvline(merged_data.index[int(len(merged_data) * 0.7)], c='black')

# %% [markdown]
# ### Step2. 데이터 Split

# %%
X_train = merged_data[merged_data['data_type'] == 'train'].iloc[:, :4]
y_train = merged_data[merged_data['data_type'] == 'train'].iloc[:, -2].values

X_test = merged_data[merged_data['data_type'] == 'test'].iloc[:, :4]
y_test = merged_data[merged_data['data_type'] == 'test'].iloc[:, -2].values

print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (492, 4)
# Test data shape: (492, 4)

# %% [markdown]
# ### Step3. 데이터 정규화

# %%
# train 데이터를 기반으로 train/test 데이터에 대하여 standard scaling 적용 (평균 0, 분산 1) 
scaler = StandardScaler()
scaler = scaler.fit(X_train)

# %%
X_train = pd.DataFrame(scaler.transform(X_train), 
                       columns=X_train.columns, 
                       index=X_train.index)
X_test = pd.DataFrame(scaler.transform(X_test), 
                      columns=X_test.columns, 
                      index=X_test.index)

# %% [markdown]
# ---

# %% [markdown]
# # 2. Autoencoders

# %% [markdown]
# ### simple autoencoders
# ANN(인공신경망)으로 구성된 autoencoders구조 실습

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# %%
X_train.shape
# Out:
# (492, 4)

# %%
# Shape of input and latent variable

input_dim = 4

# Encoder structure
encoder1_dim = 16
encoder2_dim = 16

latent_dim = 8

# Decoder structure
decoder1_dim = 16
decoder2_dim = 16

# %% [markdown]
# ### Step 1. Train 데이터 기반 AE(Autoencoders)모델 적합

# %% [markdown]
# - `hidden_layer_sizes`: 뉴런넷 hidden layer의 사이즈를 tuple로 받으며, 순차적으로 연결됨
# - `activation`: non-linear activation 사용
# - `learninig_rate_init`: 초기 학습률
# - `max_iter`: 학습 반복수
# - `tol`: stop 기준
# - `verbose`: 학습 log 출력

# %%
ae = MLPRegressor(hidden_layer_sizes = (encoder1_dim, encoder2_dim, latent_dim, decoder1_dim, decoder2_dim), 
                   activation = 'tanh', 
                   solver = 'adam', 
                   learning_rate_init = 0.01, 
                   max_iter = 100, 
                   tol = 0.0001, 
                   verbose = True)

# %%
# AE 모델 적합
ae.fit(X_train, X_train)
# Out:
# Iteration 1, loss = 0.48622094
# Iteration 2, loss = 0.30217653
# Iteration 3, loss = 0.19289695
# Iteration 4, loss = 0.14269423
# Iteration 5, loss = 0.12549822
# Iteration 6, loss = 0.11958680
# Iteration 7, loss = 0.10436396
# Iteration 8, loss = 0.08757218
# Iteration 9, loss = 0.07228396
# Iteration 10, loss = 0.06493532
# Iteration 11, loss = 0.05699677
# Iteration 12, loss = 0.05106923
# Iteration 13, loss = 0.04643306
# Iteration 14, loss = 0.04352947
# Iteration 15, loss = 0.03936037
# Iteration 16, loss = 0.03481428
# Iteration 17, loss = 0.03118232
# Iteration 18, loss = 0.02957503
# Iteration 19, loss = 0.02725893
# Iteration 20, loss = 0.02450041
# Iteration 21, loss = 0.02205942
# Iteration 22, loss = 0.02021804
# Iteration 23, loss = 0.01848081
# Iteration 24, loss = 0.01667171
# Iteration 25, loss = 0.01544319
# Iteration 26, loss = 0.01417328
# Iteration 27, loss = 0.01300083
# Iteration 28, loss = 0.01177619
# Iteration 29, loss = 0.01078142
# Iteration 30, loss = 0.01007812
# Iteration 31, loss = 0.00918934
# Iteration 32, loss = 0.00878456
# Iteration 33, loss = 0.00824894
# Iteration 34, loss = 0.00784639
# Iteration 35, loss = 0.00699758
# Iteration 36, loss = 0.00650932
# Iteration 37, loss = 0.00611138
# Iteration 38, loss = 0.00611322
# Iteration 39, loss = 0.00560571
# Iteration 40, loss = 0.00529103
# Iteration 41, loss = 0.00467486
# Iteration 42, loss = 0.00450217
# Iteration 43, loss = 0.00413385
# Iteration 44, loss = 0.00386858
# Iteration 45, loss = 0.00391687
# Iteration 46, loss = 0.00361315
# Iteration 47, loss = 0.00328362
# Iteration 48, loss = 0.00322818
# Iteration 49, loss = 0.00308007
# Iteration 50, loss = 0.00267504
# Iteration 51, loss = 0.00253254
# Iteration 52, loss = 0.00235313
# Iteration 53, loss = 0.00220368
# Iteration 54, loss = 0.00207977
# Iteration 55, loss = 0.00208954
# Iteration 56, loss = 0.00199380
# Iteration 57, loss = 0.00227683
# Iteration 58, loss = 0.00208699
# Iteration 59, loss = 0.00200709
# Iteration 60, loss = 0.00205161
# Iteration 61, loss = 0.00199039
# Iteration 62, loss = 0.00194829
# Iteration 63, loss = 0.00154071
# Iteration 64, loss = 0.00160682
# Iteration 65, loss = 0.00155737
# Iteration 66, loss = 0.00152778
# Iteration 67, loss = 0.00141455
# Iteration 68, loss = 0.00133935
# Iteration 69, loss = 0.00140362
# Iteration 70, loss = 0.00219529
# Iteration 71, loss = 0.00160328
# Iteration 72, loss = 0.00209788
# Iteration 73, loss = 0.00141623
# Iteration 74, loss = 0.00150700
# Iteration 75, loss = 0.00125290
# Iteration 76, loss = 0.00128148
# Iteration 77, loss = 0.00207387
# Iteration 78, loss = 0.00122050
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(activation='tanh', hidden_layer_sizes=(16, 16, 8, 16, 16),
#              learning_rate_init=0.01, max_iter=100, verbose=True)

# %% [markdown]
# ### Step 2. 적합된 모델을 기반으로 train/test 데이터의 anomaly score 도출

# %%
def score(model,X):
    scores_ = np.square((X.values-ae.predict(X))).mean(axis=1)
    return scores_

# %%
# train/test 데이터의 ae score 도출
ae_train = score(ae, X_train)
ae_test = score(ae, X_test)

# %%
# train/test 데이터의 anomaly score 분포 시각화
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize = (8, 8))

sns.histplot(ae_train, bins=100, kde=True, color='blue', ax=ax1)
sns.histplot(ae_test, bins=100, kde=True, color='red', ax=ax2)
ax1.set_title("Train Data")
ax2.set_title("Test Data")
# Out:
# Text(0.5, 1.0, 'Test Data')

# %% [markdown]
# ### Step 3. Threshold 탐색

# %%
# threshold 탐색
# score의 min ~ max 범위를 num_step개로 균등 분할한 threshold에 대하여 best threshold 탐색 
def search_best_threshold(score, y_true, num_step):
    best_f1 = 0.5
    best_threshold = None
    for threshold in np.linspace(min(score), max(score), num_step):
        y_pred = threshold < score

        f1 = f1_score(y_true, y_pred)
        if f1 > best_f1:
            best_f1 = f1
            best_threshold = threshold

    print('Best threshold: ', round(best_threshold, 4))
    print('Best F1 Score:', round(best_f1, 4))
    return best_threshold

# %%
# best threshold 도출
ae_best_threshold = search_best_threshold(ae_test, y_test, num_step=1000)
# Out:
# Best threshold:  66.3527
# Best F1 Score: 0.9338

# %% [markdown]
# ### Step 4. Best threshold를 기반으로 이상치 탐지 모형 평가

# %%
# 최종 결과 도출
ae_scores = pd.DataFrame(index=merged_data.index)
ae_scores['score'] = list(np.hstack([ae_train, ae_test]))
ae_scores['anomaly'] = ae_best_threshold < ae_scores['score']
ae_scores.head()
# Out:
#                         score  anomaly
# 2004-02-12 10:32:39  0.065580    False
# 2004-02-12 10:42:39  0.013208    False
# 2004-02-12 10:52:39  0.006329    False
# 2004-02-12 11:02:39  0.008484    False
# 2004-02-12 11:12:39  0.004308    False

# %%
# anomaly score plot 도출
def draw_plot(scores, threshold):
    normal_scores = scores[scores['anomaly'] == False]
    abnormal_scores = scores[scores['anomaly'] == True]

    plt.figure(figsize = (12,5))
    plt.scatter(normal_scores.index, normal_scores['score'], label='Normal', c='blue', s=3)
    plt.scatter(abnormal_scores.index, abnormal_scores['score'], label='Abnormal', c='red', s=3)
    
    plt.axhline(threshold, c='green', alpha=0.7)
    plt.axvline(merged_data.index[int(len(merged_data) * 0.5)], c='orange', ls='--')
    
    plt.xlabel('Date')
    plt.ylabel('Anomaly Score')
    plt.legend()
    
    plt.show()

# %%
# 전체 데이터의 anomaly score 확인
draw_plot(ae_scores, ae_best_threshold)

# %%
# FRR, FAR, F1 score 도출
def calculate_metric(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[True, False])
    tp, fn, fp, tn = cm.ravel()
    
    frr = fp / (fp + tn)
    far = fn / (fn + tp) 
    
    f1 = f1_score(y_true, y_pred)
    
    return frr, far, f1

# %%
# F1 Score: 0.9291
frr, far, f1 = calculate_metric(y_test, ae_scores['anomaly'].iloc[int(len(merged_data) * 0.5):])

print("**  FRR: {}  |  FAR: {}  |  F1 Score: {}".format(round(frr, 4), round(far, 4), round(f1, 4)))
# Out:
# **  FRR: 0.2143  |  FAR: 0.0  |  F1 Score: 0.9338

# %% [markdown]
# ---
